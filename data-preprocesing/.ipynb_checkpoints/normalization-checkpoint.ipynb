# %%
import os
from multiprocessing import Pool
import numpy as np # linear algebra

from skimage import io, img_as_float

from sklearn import preprocessing
from sklearn.externals import joblib

# %%
out_dir = "../input/normalized-images/"
in_dir = "../input/preprocessed-images/"
scaler_filename = "../models/images_StandardScaler.save"
shape = 256

# %%
def normalize_image(image_dir):
    image = np.array(io.imread(in_dir+image_dir))
                
    # Load scaler
    scaler = joblib.load(scaler_filename)
   
    # standarization or normalization
    image = image.reshape(1,-1)
    
    image = scaler.transform(image)
    image = image.reshape(shape,shape)

    io.imsave(out_dir+image_dir,image)    
    print("normalized image saved in: "+out_dir+image_dir)

# %%
if not os.path.exists(out_dir):
    os.mkdir(out_dir)

processes = 4

dir_list = np.array(os.listdir(in_dir))

pool = Pool(processes=processes)  # Num of CPUs

pool.map(normalize_image, dir_list, chunksize = 8)

pool.close()
pool.terminate()
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# normalized image saved in: ../input/normalized-images/a1c59822cc89ee12.jpg
# normalized image saved in: ../input/normalized-images/ae095c33b71fba55.jpg
# normalized image saved in: ../input/normalized-images/4e35bbf0d79f276e.jpg
# normalized image saved in: ../input/normalized-images/0fde08382dea186f.jpg
# normalized image saved in: ../input/normalized-images/b2421043c05de2c3.jpg
# normalized image saved in: ../input/normalized-images/fed1db445711bb27.jpg
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# normalized image saved in: ../input/normalized-images/96b6642de381e98e.jpg
# normalized image saved in: ../input/normalized-images/50ceb1957b1bc493.jpg
# normalized image saved in: ../input/normalized-images/38dfaf1ec68511e2.jpg
# normalized image saved in: ../input/normalized-images/258e9b477afdf9e2.jpg
# normalized image saved in: ../input/normalized-images/30df83826fca2af5.jpg
# normalized image saved in: ../input/normalized-images/74b777603be6ebf1.jpg
# normalized image saved in: ../input/normalized-images/294167a2e8a7378b.jpg
# normalized image saved in: ../input/normalized-images/ee4dde67b682ddd8.jpg
# normalized image saved in: ../input/normalized-images/6536d9b76fde53b3.jpg
# normalized image saved in: ../input/normalized-images/f642dde6c168d098.jpg
# normalized image saved in: ../input/normalized-images/bae339d8dffce82e.jpg
# normalized image saved in: ../input/normalized-images/b081b80b1c55e039.jpg
# normalized image saved in: ../input/normalized-images/5577bfd5ffa4d61f.jpg
# normalized image saved in: ../input/normalized-images/897440b31e764733.jpg
# normalized image saved in: ../input/normalized-images/2628bdc9b4f99ba5.jpg
# normalized image saved in: ../input/normalized-images/dd2498ae0afe37c8.jpg
# normalized image saved in: ../input/normalized-images/489ad4ee9b330bc6.jpg
# normalized image saved in: ../input/normalized-images/842ab25594475716.jpg
# normalized image saved in: ../input/normalized-images/5db7962fe5c99590.jpg
# normalized image saved in: ../input/normalized-images/c20c3a6336fa833b.jpg
# normalized image saved in: ../input/normalized-images/2b97ec37316273e8.jpg
# normalized image saved in: ../input/normalized-images/995bee7d944b2c87.jpg
# normalized image saved in: ../input/normalized-images/bde677286d9954b8.jpg
# normalized image saved in: ../input/normalized-images/c7eca1c08e255493.jpg
# normalized image saved in: ../input/normalized-images/7d02d405935964f1.jpg
# normalized image saved in: ../input/normalized-images/318266acd6c995cd.jpg
# normalized image saved in: ../input/normalized-images/70f5b512207bc1fd.jpg
# normalized image saved in: ../input/normalized-images/0d3b8f4f0657f7e4.jpg
# normalized image saved in: ../input/normalized-images/1642d4d4d0abc818.jpg
# normalized image saved in: ../input/normalized-images/f32fbaa24c8547da.jpg
# normalized image saved in: ../input/normalized-images/66cf9f6eb82b35a2.jpg
# normalized image saved in: ../input/normalized-images/0f6c405fb51be583.jpg
# normalized image saved in: ../input/normalized-images/6cfd91255776bf1d.jpg
# normalized image saved in: ../input/normalized-images/ffb5cec9de0828d1.jpg
# normalized image saved in: ../input/normalized-images/9aa86dd2388debf8.jpg
# normalized image saved in: ../input/normalized-images/e18d7ba6c1ba097b.jpg
# normalized image saved in: ../input/normalized-images/b9cecc901ac920a7.jpg
# normalized image saved in: ../input/normalized-images/1ebc24e1b96e2294.jpg
# normalized image saved in: ../input/normalized-images/1a154e7912b6f8e5.jpg
# normalized image saved in: ../input/normalized-images/3cb627af88a99269.jpg
# normalized image saved in: ../input/normalized-images/bcfe0d5c25095ffc.jpg
# normalized image saved in: ../input/normalized-images/7d5bcd4e672cabee.jpg
# normalized image saved in: ../input/normalized-images/4da3969c86a28d48.jpg
# normalized image saved in: ../input/normalized-images/b903fa8ea4221407.jpg
# normalized image saved in: ../input/normalized-images/e44c6e0a6288b255.jpg
# normalized image saved in: ../input/normalized-images/d81ea9d6c5c3478b.jpg
# normalized image saved in: ../input/normalized-images/fb8b6701b2fb19fd.jpg
# normalized image saved in: ../input/normalized-images/27f82302b85c2549.jpg
# normalized image saved in: ../input/normalized-images/a9ba3679fda3dc42.jpg
# normalized image saved in: ../input/normalized-images/8b461ae0a228d8b1.jpg
# normalized image saved in: ../input/normalized-images/401b153abd9eafb0.jpg
# normalized image saved in: ../input/normalized-images/d3877281778d55f2.jpg
# normalized image saved in: ../input/normalized-images/a6a3f467314b9ebb.jpg
# normalized image saved in: ../input/normalized-images/2e5fdb834608f79b.jpg
# normalized image saved in: ../input/normalized-images/8197ecfecd01757d.jpg
# normalized image saved in: ../input/normalized-images/a079bcfe4f56a5be.jpg
# normalized image saved in: ../input/normalized-images/0e7be9612d8ea10d.jpg
# normalized image saved in: ../input/normalized-images/c91deef1ca967770.jpg
# normalized image saved in: ../input/normalized-images/b2ef09f00a96e578.jpg
# normalized image saved in: ../input/normalized-images/ef2dd3bfe2abb45d.jpg
# normalized image saved in: ../input/normalized-images/8512bab134252380.jpg
# normalized image saved in: ../input/normalized-images/d855023f8eab6787.jpg
# normalized image saved in: ../input/normalized-images/e2c802b78476ce89.jpg
# normalized image saved in: ../input/normalized-images/eef488a4f47454e8.jpg
# normalized image saved in: ../input/normalized-images/f817a4b7dde2f884.jpg
# normalized image saved in: ../input/normalized-images/53899a1b228dfeb0.jpg
# normalized image saved in: ../input/normalized-images/e2fc4ab8bd30480a.jpg
# normalized image saved in: ../input/normalized-images/13c6a04e058c1369.jpg
# normalized image saved in: ../input/normalized-images/f0b5f47fc8884606.jpg
# normalized image saved in: ../input/normalized-images/c06483867427b0c5.jpg
# normalized image saved in: ../input/normalized-images/a4f52661d43cddef.jpg
# normalized image saved in: ../input/normalized-images/11a9b4fb9ad15315.jpg
# normalized image saved in: ../input/normalized-images/9c233894ca335963.jpg
# normalized image saved in: ../input/normalized-images/a0ae26a053f68cf1.jpg
# normalized image saved in: ../input/normalized-images/b39f2c1284ba49fc.jpg
# normalized image saved in: ../input/normalized-images/a56918429c224d97.jpg
# normalized image saved in: ../input/normalized-images/a891174cdf5cdfc9.jpg
# normalized image saved in: ../input/normalized-images/47d86abfdbbf1490.jpg
# normalized image saved in: ../input/normalized-images/6cd6d5cbd007892b.jpg
# normalized image saved in: ../input/normalized-images/5831e725cf8dbd28.jpg
# normalized image saved in: ../input/normalized-images/f3d119c357d60670.jpg
# normalized image saved in: ../input/normalized-images/bc35aecee8f8476c.jpg
# normalized image saved in: ../input/normalized-images/e26a19e6ce2ce913.jpg
# normalized image saved in: ../input/normalized-images/ef194254cf3391bb.jpg
# normalized image saved in: ../input/normalized-images/e6b6cb0e02d646b9.jpg
# normalized image saved in: ../input/normalized-images/ad00a5cfa2415e9e.jpg
# normalized image saved in: ../input/normalized-images/9acfd81a1a0cc854.jpg
# normalized image saved in: ../input/normalized-images/18090af970b4f00e.jpg
# normalized image saved in: ../input/normalized-images/bc8a558964f02eb5.jpg
# normalized image saved in: ../input/normalized-images/c318592ea621802e.jpg
# normalized image saved in: ../input/normalized-images/896e5d2fad44ee3f.jpg
# normalized image saved in: ../input/normalized-images/aa9c0627d4136a0f.jpg
# normalized image saved in: ../input/normalized-images/f822f861f737281e.jpg
# normalized image saved in: ../input/normalized-images/c56bb778d1c8e9b3.jpg
# normalized image saved in: ../input/normalized-images/daf1fedf7b43ee58.jpg
# normalized image saved in: ../input/normalized-images/8afde7223581aac9.jpg
# normalized image saved in: ../input/normalized-images/7b49d0ddca4db235.jpg
# normalized image saved in: ../input/normalized-images/7adf3f4ee48b423e.jpg
# normalized image saved in: ../input/normalized-images/77828d8f8b85da40.jpg
# normalized image saved in: ../input/normalized-images/f2925b66179e7015.jpg
# normalized image saved in: ../input/normalized-images/d6272ccecf10c0a8.jpg
# normalized image saved in: ../input/normalized-images/18d1ee006043dc0b.jpg
# normalized image saved in: ../input/normalized-images/173950f095640e00.jpg
# normalized image saved in: ../input/normalized-images/2999ee213d9842e9.jpg
# normalized image saved in: ../input/normalized-images/873f2dfc2fc21102.jpg
# normalized image saved in: ../input/normalized-images/26fbe35544906672.jpg
# normalized image saved in: ../input/normalized-images/3cabf3d6b279f4d9.jpg
# normalized image saved in: ../input/normalized-images/f1cc54cc6b2fdc60.jpg
# normalized image saved in: ../input/normalized-images/579d5297a77a9217.jpg
# normalized image saved in: ../input/normalized-images/ab470ee0a8ba5849.jpg
# normalized image saved in: ../input/normalized-images/964e4b59e1f8e635.jpg
# normalized image saved in: ../input/normalized-images/54ef708f5fef63dc.jpg
# normalized image saved in: ../input/normalized-images/ae258a897b4d4c9d.jpg
# normalized image saved in: ../input/normalized-images/7f13d1b3dc57c5af.jpg
# normalized image saved in: ../input/normalized-images/9178fe8516294c49.jpg
# normalized image saved in: ../input/normalized-images/66a8427fab174116.jpg
# normalized image saved in: ../input/normalized-images/ae85b21335af12b9.jpg
# normalized image saved in: ../input/normalized-images/599671cd0ff871fc.jpg
# normalized image saved in: ../input/normalized-images/0873b935b9776f34.jpg
# normalized image saved in: ../input/normalized-images/2f9b1acb1ab18c06.jpg
# normalized image saved in: ../input/normalized-images/d5c710be28159671.jpg
# normalized image saved in: ../input/normalized-images/d4d611dafb3ee84d.jpg
# normalized image saved in: ../input/normalized-images/074a53f23e9ad8a1.jpg
# normalized image saved in: ../input/normalized-images/4563109a5588a078.jpg
# normalized image saved in: ../input/normalized-images/adbf48fe8eaf3de3.jpg
# normalized image saved in: ../input/normalized-images/0d40b1cc2675a644.jpg
# normalized image saved in: ../input/normalized-images/4d1b1d4d49bca76c.jpg
# normalized image saved in: ../input/normalized-images/e1dc85364a08e3e6.jpg
# normalized image saved in: ../input/normalized-images/983b286d846eacd6.jpg
# normalized image saved in: ../input/normalized-images/5d50075ffe130f98.jpg
# normalized image saved in: ../input/normalized-images/57e5ea944b3712db.jpg
# normalized image saved in: ../input/normalized-images/e10c4b86c05b364c.jpg
# normalized image saved in: ../input/normalized-images/71c14353adaffdad.jpg
# normalized image saved in: ../input/normalized-images/f1551f118d2cb7b2.jpg
# normalized image saved in: ../input/normalized-images/c04ff453e5862ec4.jpg
# normalized image saved in: ../input/normalized-images/6d2f16aa10fe8b17.jpg
# normalized image saved in: ../input/normalized-images/302fbef64032398c.jpg
# normalized image saved in: ../input/normalized-images/4567ff3f4d73aaab.jpg
# normalized image saved in: ../input/normalized-images/da7219ee6db161fe.jpg
# normalized image saved in: ../input/normalized-images/e2e8c43675301647.jpg
# normalized image saved in: ../input/normalized-images/8fe3f8db7fd4634f.jpg
# normalized image saved in: ../input/normalized-images/4f824846c76acb9a.jpg
# normalized image saved in: ../input/normalized-images/278cae55fa53ba7c.jpg
# normalized image saved in: ../input/normalized-images/0de1417b4a77fd0f.jpg
# normalized image saved in: ../input/normalized-images/a4c9e0350828605e.jpg
# normalized image saved in: ../input/normalized-images/bf09a59c48bfd74b.jpg
# normalized image saved in: ../input/normalized-images/52547c45fe2a8c51.jpg
# normalized image saved in: ../input/normalized-images/62c548739212eac9.jpg
# normalized image saved in: ../input/normalized-images/4fee6bbe4931a45d.jpg
# normalized image saved in: ../input/normalized-images/f45ee539701b8bd9.jpg
# normalized image saved in: ../input/normalized-images/5a2e88ff1c430f9c.jpg
# normalized image saved in: ../input/normalized-images/21ff5da3a9474c0e.jpg
# normalized image saved in: ../input/normalized-images/ed23090ebfc64e69.jpg
# normalized image saved in: ../input/normalized-images/2424ef7378a01feb.jpg
# normalized image saved in: ../input/normalized-images/0225ff7ef70dba23.jpg
# normalized image saved in: ../input/normalized-images/ebe6fcebcb1842a0.jpg
# normalized image saved in: ../input/normalized-images/68ca89afaf6ee4ae.jpg
# normalized image saved in: ../input/normalized-images/60e448b570871b6c.jpg
# normalized image saved in: ../input/normalized-images/f2264ab5bd8cc786.jpg
# normalized image saved in: ../input/normalized-images/69b0cee4353ea122.jpg
# normalized image saved in: ../input/normalized-images/5578dc375b2bb740.jpg
# normalized image saved in: ../input/normalized-images/c5434add506acf6d.jpg
# normalized image saved in: ../input/normalized-images/77cf937e0eb64496.jpg
# normalized image saved in: ../input/normalized-images/e5284b827c1b5f18.jpg
# normalized image saved in: ../input/normalized-images/9aaf7b53ff79fe6c.jpg
# normalized image saved in: ../input/normalized-images/2b5266d0aebfe659.jpg
# normalized image saved in: ../input/normalized-images/f5a6da31f95b8696.jpg
# normalized image saved in: ../input/normalized-images/14a61bae1d48dd86.jpg
# normalized image saved in: ../input/normalized-images/af63c547bbbbefb7.jpg
# normalized image saved in: ../input/normalized-images/801ed871fc2352d4.jpg
# normalized image saved in: ../input/normalized-images/6011ced5e616a515.jpg
# normalized image saved in: ../input/normalized-images/be9b96d3bd2d8f8f.jpg
# normalized image saved in: ../input/normalized-images/a66ee27cc6ca47f5.jpg
# normalized image saved in: ../input/normalized-images/500d19551475bff7.jpg
# normalized image saved in: ../input/normalized-images/80e80ab470d59441.jpg
# normalized image saved in: ../input/normalized-images/009d24b7bbde3d67.jpg
# normalized image saved in: ../input/normalized-images/244d823abc91b17e.jpg
# normalized image saved in: ../input/normalized-images/fc0180193e2beef5.jpg
# normalized image saved in: ../input/normalized-images/10dd37e49d57c0cb.jpg
# normalized image saved in: ../input/normalized-images/d97aa5775e5b5416.jpg
# normalized image saved in: ../input/normalized-images/a2a27a5945594586.jpg
# normalized image saved in: ../input/normalized-images/f22b47998b5842c4.jpg
# normalized image saved in: ../input/normalized-images/bfe7d423743af7e8.jpg
# normalized image saved in: ../input/normalized-images/ce5693cdcd8f37b8.jpg
# normalized image saved in: ../input/normalized-images/c6bb48442c112100.jpg
# normalized image saved in: ../input/normalized-images/923cca1471f7be46.jpg
# normalized image saved in: ../input/normalized-images/310b012e7b11c993.jpg
# normalized image saved in: ../input/normalized-images/615cf25a268d8f8b.jpg
# normalized image saved in: ../input/normalized-images/c6ad319789a0fd30.jpg
# normalized image saved in: ../input/normalized-images/be1ffced1e88f46c.jpg
# normalized image saved in: ../input/normalized-images/439e8cc12a50073c.jpg
# normalized image saved in: ../input/normalized-images/d502cdb41eebc7b9.jpg
# normalized image saved in: ../input/normalized-images/5994db3e8418e32e.jpg
# normalized image saved in: ../input/normalized-images/8e4aad9102e1d62a.jpg
# normalized image saved in: ../input/normalized-images/ef682181de13ebad.jpg
# normalized image saved in: ../input/normalized-images/a287c6a3363dee23.jpg
# normalized image saved in: ../input/normalized-images/e9ca41064c9947f2.jpg
# normalized image saved in: ../input/normalized-images/9073bda2bac994ca.jpg
# normalized image saved in: ../input/normalized-images/e349bd29a8b6c435.jpg
# normalized image saved in: ../input/normalized-images/36041f3e366f16b6.jpg
# normalized image saved in: ../input/normalized-images/d15a3358e58bbaa6.jpg
# normalized image saved in: ../input/normalized-images/d6da776e49ebfaa1.jpg
# normalized image saved in: ../input/normalized-images/1fd9660d8a765a80.jpg
# normalized image saved in: ../input/normalized-images/1a1380d3b3e4ba67.jpg
# normalized image saved in: ../input/normalized-images/3490d5e46cd29f30.jpg
# normalized image saved in: ../input/normalized-images/3dfeb4b35070d63f.jpg
# normalized image saved in: ../input/normalized-images/86b0ad64a9d1b752.jpg
# normalized image saved in: ../input/normalized-images/ac87334f89764a51.jpg
# normalized image saved in: ../input/normalized-images/59db82d4ae3f335f.jpg
# normalized image saved in: ../input/normalized-images/bffbdd67c1620bc9.jpg
# normalized image saved in: ../input/normalized-images/03dec8d5fe60d83f.jpg
# normalized image saved in: ../input/normalized-images/76e7669f8ef614f5.jpg
# normalized image saved in: ../input/normalized-images/a8938409092d680a.jpg
# normalized image saved in: ../input/normalized-images/4dd72331fbe91bfd.jpg
# normalized image saved in: ../input/normalized-images/9c9eaf3169b68b2c.jpg
# normalized image saved in: ../input/normalized-images/b42653184c81aac0.jpg
# normalized image saved in: ../input/normalized-images/6bd73f12bfeeeb72.jpg
# normalized image saved in: ../input/normalized-images/e0a9ee8c93af2983.jpg
# normalized image saved in: ../input/normalized-images/60c93ad870cf10ce.jpg
# normalized image saved in: ../input/normalized-images/b3ed6e71e89082de.jpg
# normalized image saved in: ../input/normalized-images/9f8a9df5ac052ad5.jpg
# normalized image saved in: ../input/normalized-images/c4560d7ccbb52044.jpg
# normalized image saved in: ../input/normalized-images/82cedecb025e2a03.jpg
# normalized image saved in: ../input/normalized-images/cba7c5766cae046d.jpg
# normalized image saved in: ../input/normalized-images/508df2d97f1bf94b.jpg
# normalized image saved in: ../input/normalized-images/63c53b2a6a2912e7.jpg
# normalized image saved in: ../input/normalized-images/2895022280991a01.jpg
# normalized image saved in: ../input/normalized-images/4f2a07aa56904886.jpg
# normalized image saved in: ../input/normalized-images/e99e875de07372f4.jpg
# normalized image saved in: ../input/normalized-images/8de7b46da49af60f.jpg
# normalized image saved in: ../input/normalized-images/0f89e768adb12dc5.jpg
# normalized image saved in: ../input/normalized-images/5de2912fff8984ce.jpg
# normalized image saved in: ../input/normalized-images/e76e4024b51f3150.jpg
# normalized image saved in: ../input/normalized-images/ec65d29eef815d96.jpg
# normalized image saved in: ../input/normalized-images/235baf1fdf74b71f.jpg
# normalized image saved in: ../input/normalized-images/b10443c23bf90e8a.jpg
# normalized image saved in: ../input/normalized-images/f546b78a7f6fc4b5.jpg
# normalized image saved in: ../input/normalized-images/bbb52be1f1b9d8de.jpg
# normalized image saved in: ../input/normalized-images/c784f6612a1682a3.jpg
# normalized image saved in: ../input/normalized-images/aae72ef0395cd7f9.jpg
# normalized image saved in: ../input/normalized-images/785b5c4c5522ed5d.jpg
# normalized image saved in: ../input/normalized-images/0d526b7190d27e47.jpg
# normalized image saved in: ../input/normalized-images/720efbc9906d3dfc.jpg
# normalized image saved in: ../input/normalized-images/1dc56ad3a0101d50.jpg
# normalized image saved in: ../input/normalized-images/06e531b31f1b3c4e.jpg
# normalized image saved in: ../input/normalized-images/4689c0ac6958b36e.jpg
# normalized image saved in: ../input/normalized-images/59d9ecae34387bbf.jpg
# normalized image saved in: ../input/normalized-images/4f265998bfa1c91b.jpg
# normalized image saved in: ../input/normalized-images/69916dbd131e48ec.jpg
# normalized image saved in: ../input/normalized-images/2e0da2c1b6728b85.jpg
# normalized image saved in: ../input/normalized-images/5be5e5760a473102.jpg
# normalized image saved in: ../input/normalized-images/bef6cd30ce0221c3.jpg
# normalized image saved in: ../input/normalized-images/bf0e9f6ed8533e5c.jpg
# normalized image saved in: ../input/normalized-images/8f1d6df9a4242ef7.jpg
# normalized image saved in: ../input/normalized-images/2a8c61891fa54780.jpg
# normalized image saved in: ../input/normalized-images/48922bb42380011e.jpg
# normalized image saved in: ../input/normalized-images/7b4ca28dcf236d35.jpg
# normalized image saved in: ../input/normalized-images/19120956e8e6ef32.jpg
# normalized image saved in: ../input/normalized-images/b6fd2d875b5ee92a.jpg
# normalized image saved in: ../input/normalized-images/a19e545e0d7ed667.jpg
# normalized image saved in: ../input/normalized-images/18bbeb5eefb17463.jpg
# normalized image saved in: ../input/normalized-images/612a913b07f4b54d.jpg
# normalized image saved in: ../input/normalized-images/4414180613fc886f.jpg
# normalized image saved in: ../input/normalized-images/4b68419857569d86.jpg
# normalized image saved in: ../input/normalized-images/e609c8a415e165ec.jpg
# normalized image saved in: ../input/normalized-images/c650b6cd5d747d0b.jpg
# normalized image saved in: ../input/normalized-images/c7c1b46c2ed8566e.jpg
# normalized image saved in: ../input/normalized-images/b121494a69b9e9e5.jpg
# normalized image saved in: ../input/normalized-images/7fa6ddf9a113b655.jpg
# normalized image saved in: ../input/normalized-images/f37060388b58ba0d.jpg
# normalized image saved in: ../input/normalized-images/832d8d901c2e0444.jpg
# normalized image saved in: ../input/normalized-images/e4e5d6ba793c3428.jpg
# normalized image saved in: ../input/normalized-images/5d426e410e6c3157.jpg
# normalized image saved in: ../input/normalized-images/c7b750a060c460be.jpg
# normalized image saved in: ../input/normalized-images/c8730c9ae3aee710.jpg
# normalized image saved in: ../input/normalized-images/b1c6426c5ff08962.jpg
# normalized image saved in: ../input/normalized-images/e5c2a3a2228833ed.jpg
# normalized image saved in: ../input/normalized-images/b5757b853085e75a.jpg
# normalized image saved in: ../input/normalized-images/6ee22320e4ddc6f1.jpg
# normalized image saved in: ../input/normalized-images/92e5ea1edaf9f8c9.jpg
# normalized image saved in: ../input/normalized-images/f3131096617b9f30.jpg
# normalized image saved in: ../input/normalized-images/dd3b15826db0ee8b.jpg
# normalized image saved in: ../input/normalized-images/69f796bd0b84d85a.jpg
# normalized image saved in: ../input/normalized-images/cb7ff497e7b795f3.jpg
# normalized image saved in: ../input/normalized-images/49fe33b28f993255.jpg
# normalized image saved in: ../input/normalized-images/88f2b7ee5826ebda.jpg
# normalized image saved in: ../input/normalized-images/ccbc929e37451626.jpg
# normalized image saved in: ../input/normalized-images/04b836dadb6be345.jpg
# normalized image saved in: ../input/normalized-images/b84cd975aea4f445.jpg
# normalized image saved in: ../input/normalized-images/e683a35094052af4.jpg
# normalized image saved in: ../input/normalized-images/f841e13dee94c1df.jpg
# normalized image saved in: ../input/normalized-images/842935a8dbb0eeab.jpg
# normalized image saved in: ../input/normalized-images/ae8b5025777a816d.jpg
# normalized image saved in: ../input/normalized-images/fb8eec9c9d5824a6.jpg
# normalized image saved in: ../input/normalized-images/6cce3745aa4af5be.jpg
# normalized image saved in: ../input/normalized-images/5cf5c0323448a339.jpg
# normalized image saved in: ../input/normalized-images/60afacdfbe85f586.jpg
# normalized image saved in: ../input/normalized-images/654c14471757b344.jpg
# normalized image saved in: ../input/normalized-images/98619e7ec0a9cf27.jpg
# normalized image saved in: ../input/normalized-images/deef256400260d3d.jpg
# normalized image saved in: ../input/normalized-images/2baf8d1c38f567b1.jpg
# normalized image saved in: ../input/normalized-images/e7e89f5ebdba3f1e.jpg
# normalized image saved in: ../input/normalized-images/558beaf47f68513e.jpg
# normalized image saved in: ../input/normalized-images/1bd063519989d527.jpg
# normalized image saved in: ../input/normalized-images/254712cbd1c5baa5.jpg
# normalized image saved in: ../input/normalized-images/fcde26c88b52b4c2.jpg
# normalized image saved in: ../input/normalized-images/9fb08043486ad3ab.jpg
# normalized image saved in: ../input/normalized-images/5521d5a1709ae82f.jpg
# normalized image saved in: ../input/normalized-images/df582da611a497ec.jpg
# normalized image saved in: ../input/normalized-images/9aab02848d7ab468.jpg
# normalized image saved in: ../input/normalized-images/7b3177be80e77eed.jpg
# normalized image saved in: ../input/normalized-images/c725a2072f5ce418.jpg
# normalized image saved in: ../input/normalized-images/05a0f77464769d86.jpg
# normalized image saved in: ../input/normalized-images/a067d94d89e0f37b.jpg
# normalized image saved in: ../input/normalized-images/320d411e45660e4f.jpg
# normalized image saved in: ../input/normalized-images/97dd8280466266c8.jpg
# normalized image saved in: ../input/normalized-images/a87d1baf26d5b878.jpg
# normalized image saved in: ../input/normalized-images/39e15ca07b026d73.jpg
# normalized image saved in: ../input/normalized-images/8bc023584be002c7.jpg
# normalized image saved in: ../input/normalized-images/c795ca238577edc3.jpg
# normalized image saved in: ../input/normalized-images/a6d1bcede9b7e6d3.jpg
# normalized image saved in: ../input/normalized-images/e8e682e04c99000f.jpg
# normalized image saved in: ../input/normalized-images/bdc58a5c7a12e925.jpg
# normalized image saved in: ../input/normalized-images/7d3f7db9723849c2.jpg
# normalized image saved in: ../input/normalized-images/72ea2378077345e1.jpg
# normalized image saved in: ../input/normalized-images/8853e36e02f0deb4.jpg
# normalized image saved in: ../input/normalized-images/59cec8c49c6a9bbf.jpg
# normalized image saved in: ../input/normalized-images/ffc89339bcf49874.jpg
# normalized image saved in: ../input/normalized-images/5c382c1a3052d518.jpg
# normalized image saved in: ../input/normalized-images/93469b02d9856436.jpg
# normalized image saved in: ../input/normalized-images/9a49eaece1b2960f.jpg
# normalized image saved in: ../input/normalized-images/ff8cbbd523149a55.jpg
# normalized image saved in: ../input/normalized-images/85495fd71f1d0f59.jpg
# normalized image saved in: ../input/normalized-images/01a5a2c99899956d.jpg
# normalized image saved in: ../input/normalized-images/a6f443bb68fd7426.jpg
# normalized image saved in: ../input/normalized-images/9d896d638211b2f1.jpg
# normalized image saved in: ../input/normalized-images/a83f3b73df2850c7.jpg
# normalized image saved in: ../input/normalized-images/a5a15d39264a6ff4.jpg
# normalized image saved in: ../input/normalized-images/3f1117a05a1d99f3.jpg
# normalized image saved in: ../input/normalized-images/4d54ead425469e7a.jpg
# normalized image saved in: ../input/normalized-images/e8efba19c0e67215.jpg
# normalized image saved in: ../input/normalized-images/e94096f18e26f14e.jpg
# normalized image saved in: ../input/normalized-images/861445b09a37d62b.jpg
# normalized image saved in: ../input/normalized-images/67728d3b6ee5e78f.jpg
# normalized image saved in: ../input/normalized-images/7abbf15d6cb496c8.jpg
# normalized image saved in: ../input/normalized-images/f070ebc02e07d7ce.jpg
# normalized image saved in: ../input/normalized-images/e19952cf3a1b3f71.jpg
# normalized image saved in: ../input/normalized-images/6baa7d468af713e4.jpg
# normalized image saved in: ../input/normalized-images/169a28165f530b9b.jpg
# normalized image saved in: ../input/normalized-images/8744613a5e6f9949.jpg
# normalized image saved in: ../input/normalized-images/d4e2d51b53f54d3f.jpg
# normalized image saved in: ../input/normalized-images/b21390db4ccb3da2.jpg
# normalized image saved in: ../input/normalized-images/b062fb52698ee951.jpg
# normalized image saved in: ../input/normalized-images/f648d80227315460.jpg
# normalized image saved in: ../input/normalized-images/d22a8d073593a63a.jpg
# normalized image saved in: ../input/normalized-images/b7b558dc0a687adf.jpg
# normalized image saved in: ../input/normalized-images/0d57e44dada56124.jpg
# normalized image saved in: ../input/normalized-images/beda77e85207507b.jpg
# normalized image saved in: ../input/normalized-images/228b19d369f8c80f.jpg
# normalized image saved in: ../input/normalized-images/892c36344727841a.jpg
# normalized image saved in: ../input/normalized-images/eb421f5554fc11c1.jpg
# normalized image saved in: ../input/normalized-images/0f2ddeb0d2b56a9a.jpg
# normalized image saved in: ../input/normalized-images/1281588da7d8fdab.jpg
# normalized image saved in: ../input/normalized-images/14e7aafeb75a5130.jpg
# normalized image saved in: ../input/normalized-images/d6ae87eda86fa960.jpg
# normalized image saved in: ../input/normalized-images/7248a4f0509d12fc.jpg
# normalized image saved in: ../input/normalized-images/1a08aa0440eec4bf.jpg
# normalized image saved in: ../input/normalized-images/6735029495fb031c.jpg
# normalized image saved in: ../input/normalized-images/e153bc50bd2484ae.jpg
# normalized image saved in: ../input/normalized-images/04fe2d9dd070ff0d.jpg
# normalized image saved in: ../input/normalized-images/caf413149bf7531b.jpg
# normalized image saved in: ../input/normalized-images/a6d8b350d873e0ed.jpg
# normalized image saved in: ../input/normalized-images/507aaedbc48c51ea.jpg
# normalized image saved in: ../input/normalized-images/e2b5db11f70cdcf9.jpg
# normalized image saved in: ../input/normalized-images/77bd2abe5a38ec46.jpg
# normalized image saved in: ../input/normalized-images/8dd3eebb9a868c9d.jpg
# normalized image saved in: ../input/normalized-images/36f449aae24e5873.jpg
# normalized image saved in: ../input/normalized-images/807b4f1741e113e7.jpg
# normalized image saved in: ../input/normalized-images/09e87df63608e2cf.jpg
# normalized image saved in: ../input/normalized-images/150114d1b8ce938b.jpg
# normalized image saved in: ../input/normalized-images/073e36fa94dba80a.jpg
# normalized image saved in: ../input/normalized-images/e591e1677a018228.jpg
# normalized image saved in: ../input/normalized-images/b1e48f7221e192bf.jpg
# normalized image saved in: ../input/normalized-images/2649582266032cf3.jpg
# normalized image saved in: ../input/normalized-images/92239831fc84e43c.jpg
# normalized image saved in: ../input/normalized-images/4f4b9568aedf7286.jpg
# normalized image saved in: ../input/normalized-images/5e55daa04b7adbbd.jpg
# normalized image saved in: ../input/normalized-images/243dfb0f35d1136a.jpg
# normalized image saved in: ../input/normalized-images/e70e72f91948daeb.jpg
# normalized image saved in: ../input/normalized-images/ec0a4e329900675a.jpg
# normalized image saved in: ../input/normalized-images/2d0f35b747ccccdb.jpg
# normalized image saved in: ../input/normalized-images/eedfce6662948aee.jpg
# normalized image saved in: ../input/normalized-images/3dc474a9fd9a5002.jpg
# normalized image saved in: ../input/normalized-images/cb5340210f49566d.jpg
# normalized image saved in: ../input/normalized-images/aa9466bc27cf762c.jpg
# normalized image saved in: ../input/normalized-images/3dead2b405029061.jpg
# normalized image saved in: ../input/normalized-images/8f2d54d06eca0841.jpg
# normalized image saved in: ../input/normalized-images/35197e02a09bc6c6.jpg
# normalized image saved in: ../input/normalized-images/0873756da65f3fd6.jpg
# normalized image saved in: ../input/normalized-images/af24bd7c49b11c1c.jpg
# normalized image saved in: ../input/normalized-images/d12e277579541b51.jpg
# normalized image saved in: ../input/normalized-images/f65679d697c93646.jpg
# normalized image saved in: ../input/normalized-images/2bc19a69681fb15c.jpg
# normalized image saved in: ../input/normalized-images/bb0b531194b85896.jpg
# normalized image saved in: ../input/normalized-images/1d307e5cbff8ab76.jpg
# normalized image saved in: ../input/normalized-images/30dc490b8df5a875.jpg
# normalized image saved in: ../input/normalized-images/834546b440fcd8d8.jpg
# normalized image saved in: ../input/normalized-images/a1eb72699467a08b.jpg
# normalized image saved in: ../input/normalized-images/fee4b7776cefca8e.jpg
# normalized image saved in: ../input/normalized-images/ebedd5894ad60263.jpg
# normalized image saved in: ../input/normalized-images/679b5b97b2c00735.jpg
# normalized image saved in: ../input/normalized-images/a9f81c7a596c65ae.jpg
# normalized image saved in: ../input/normalized-images/f1ac853e5345b2dc.jpg
# normalized image saved in: ../input/normalized-images/d007270a412c194a.jpg
# normalized image saved in: ../input/normalized-images/d08a85828b3fcbdf.jpg
# normalized image saved in: ../input/normalized-images/b85b68d57c494d1b.jpg
# normalized image saved in: ../input/normalized-images/8244133097a67e32.jpg
# normalized image saved in: ../input/normalized-images/6b66d19572a1ddb4.jpg
# normalized image saved in: ../input/normalized-images/af7bbca1ede2e401.jpg
# normalized image saved in: ../input/normalized-images/d9e5a5c74e70589a.jpg
# normalized image saved in: ../input/normalized-images/93c62fe06cd5471b.jpg
# normalized image saved in: ../input/normalized-images/ec92f589f08ebe40.jpg
# normalized image saved in: ../input/normalized-images/a927214108b8cc94.jpg
# normalized image saved in: ../input/normalized-images/9550dc957c0df997.jpg
# normalized image saved in: ../input/normalized-images/7350306f43b1c4f2.jpg
# normalized image saved in: ../input/normalized-images/7469efe5ed919d66.jpg
# normalized image saved in: ../input/normalized-images/2daff94bcdffb048.jpg
# normalized image saved in: ../input/normalized-images/3519b431c9b6ae5a.jpg
# normalized image saved in: ../input/normalized-images/e0275c407e92cca3.jpg
# normalized image saved in: ../input/normalized-images/d3bcbd14ed84b209.jpg
# normalized image saved in: ../input/normalized-images/70752ba10afc3f5e.jpg
# normalized image saved in: ../input/normalized-images/a1d517055b75bf4d.jpg
# normalized image saved in: ../input/normalized-images/0e73439e81a88f2d.jpg
# normalized image saved in: ../input/normalized-images/65bc4f504a0b6d68.jpg
# normalized image saved in: ../input/normalized-images/b17ac9e235be95db.jpg
# normalized image saved in: ../input/normalized-images/b262b551f42d269e.jpg
# normalized image saved in: ../input/normalized-images/9eefb0444a07e595.jpg
# normalized image saved in: ../input/normalized-images/ca39a1d7738f1689.jpg
# normalized image saved in: ../input/normalized-images/ca2f306560b051f4.jpg
# normalized image saved in: ../input/normalized-images/7f48e790cd692bdd.jpg
# normalized image saved in: ../input/normalized-images/55666cb2fffb1803.jpg
# normalized image saved in: ../input/normalized-images/3f4f255269dd67e5.jpg
# normalized image saved in: ../input/normalized-images/cbc21ddd5d962e15.jpg
# normalized image saved in: ../input/normalized-images/d424e5e644f18f4c.jpg
# normalized image saved in: ../input/normalized-images/8e93148806a1f2bc.jpg
# normalized image saved in: ../input/normalized-images/fc3d11795ffbf560.jpg
# normalized image saved in: ../input/normalized-images/b5fb7e2bf7b77305.jpg
# normalized image saved in: ../input/normalized-images/972fab6816b25205.jpg
# normalized image saved in: ../input/normalized-images/032e8df5180cbb89.jpg
# normalized image saved in: ../input/normalized-images/23146189a2558c1e.jpg
# normalized image saved in: ../input/normalized-images/ed6a76177395a3cc.jpg
# normalized image saved in: ../input/normalized-images/05049a59d4a54103.jpg
# normalized image saved in: ../input/normalized-images/4dbeb5fd68ed4570.jpg
# normalized image saved in: ../input/normalized-images/28631b8336a31e4f.jpg
# normalized image saved in: ../input/normalized-images/9b4695e9d80b7fb5.jpg
# normalized image saved in: ../input/normalized-images/aed0896e75b0ee2a.jpg
# normalized image saved in: ../input/normalized-images/9528deed693caa37.jpg
# normalized image saved in: ../input/normalized-images/9f04eff37d478075.jpg
# normalized image saved in: ../input/normalized-images/c58b943c4aa61cce.jpg
# normalized image saved in: ../input/normalized-images/421238f60d217ce1.jpg
# normalized image saved in: ../input/normalized-images/db394ddf0449ad4e.jpg
# normalized image saved in: ../input/normalized-images/7e2b7a3df5ddf3c7.jpg
# normalized image saved in: ../input/normalized-images/ebb21d52a6e0afc6.jpg
# normalized image saved in: ../input/normalized-images/2ebf944c0dd3982a.jpg
# normalized image saved in: ../input/normalized-images/fef33ec825544328.jpg
# normalized image saved in: ../input/normalized-images/d726436f7109be97.jpg
# normalized image saved in: ../input/normalized-images/170be6dbb97a3abf.jpg
# normalized image saved in: ../input/normalized-images/8428a80becaf0512.jpg
# normalized image saved in: ../input/normalized-images/d6c56f24de045cf2.jpg
# normalized image saved in: ../input/normalized-images/9c9189598c3f5f63.jpg
# normalized image saved in: ../input/normalized-images/9d8fbc3aea0ba899.jpg
# normalized image saved in: ../input/normalized-images/a822b8697b3c1e78.jpg
# normalized image saved in: ../input/normalized-images/b4a6f8b588fba8af.jpg
# normalized image saved in: ../input/normalized-images/7007434b5af51e06.jpg
# normalized image saved in: ../input/normalized-images/23e76f0a18a0d200.jpg
# normalized image saved in: ../input/normalized-images/cebbf5fd7031463a.jpg
# normalized image saved in: ../input/normalized-images/449717fcefc45d95.jpg
# normalized image saved in: ../input/normalized-images/b7420127456091fc.jpg
# normalized image saved in: ../input/normalized-images/5aaf6b375611cdfc.jpg
# normalized image saved in: ../input/normalized-images/9412c8efce33c87e.jpg
# normalized image saved in: ../input/normalized-images/6bd809dce65846c4.jpg
# normalized image saved in: ../input/normalized-images/d7df0ba19f6b0d88.jpg
# normalized image saved in: ../input/normalized-images/eca9426344c4f3f9.jpg
# normalized image saved in: ../input/normalized-images/ee21c9821dd2957d.jpg
# normalized image saved in: ../input/normalized-images/f2949aa8a74eba32.jpg
# normalized image saved in: ../input/normalized-images/8e2eb509b79f30b4.jpg
# normalized image saved in: ../input/normalized-images/50bfe160249e4562.jpg
# normalized image saved in: ../input/normalized-images/7bf7fee58f468e2e.jpg
# normalized image saved in: ../input/normalized-images/ad5386f0c60bf7c1.jpg
# normalized image saved in: ../input/normalized-images/af6275a54a575de2.jpg
# normalized image saved in: ../input/normalized-images/87873e30806338f6.jpg
# normalized image saved in: ../input/normalized-images/6ca44da92b374614.jpg
# normalized image saved in: ../input/normalized-images/d98b721627e81d82.jpg
# normalized image saved in: ../input/normalized-images/149132f5b16f0a71.jpg
# normalized image saved in: ../input/normalized-images/2faf3e1b5a542eb7.jpg
# normalized image saved in: ../input/normalized-images/e1aa7aa9a2360ac2.jpg
# normalized image saved in: ../input/normalized-images/765c232a08ca5a23.jpg
# normalized image saved in: ../input/normalized-images/374729d6b07acbcc.jpg
# normalized image saved in: ../input/normalized-images/6d6013902d082ecc.jpg
# normalized image saved in: ../input/normalized-images/82a6d56099503121.jpg
# normalized image saved in: ../input/normalized-images/66cfeceef85b8550.jpg
# normalized image saved in: ../input/normalized-images/e7d773aa32f7d7e8.jpg
# normalized image saved in: ../input/normalized-images/50d155721ccf9062.jpg
# normalized image saved in: ../input/normalized-images/261b2d46ac1d0980.jpg
# normalized image saved in: ../input/normalized-images/458397aa1f4d01af.jpg
# normalized image saved in: ../input/normalized-images/41854b51b145f5c7.jpg
# normalized image saved in: ../input/normalized-images/5b92254ad1a95e63.jpg
# normalized image saved in: ../input/normalized-images/f9cda5458b2b0730.jpg
# normalized image saved in: ../input/normalized-images/495213ab5829de86.jpg
# normalized image saved in: ../input/normalized-images/40d4d54476411b31.jpg
# normalized image saved in: ../input/normalized-images/d1a80916936f9dd6.jpg
# normalized image saved in: ../input/normalized-images/2750ddae4b8cf971.jpg
# normalized image saved in: ../input/normalized-images/fbf0221f97813d3a.jpg
# normalized image saved in: ../input/normalized-images/531b58c420fe70cd.jpg
# normalized image saved in: ../input/normalized-images/c24a5ce673affb3c.jpg
# normalized image saved in: ../input/normalized-images/cd6a07e854ae07b1.jpg
# normalized image saved in: ../input/normalized-images/916c950d118c30e0.jpg
# normalized image saved in: ../input/normalized-images/16b30859dfc8fe55.jpg
# normalized image saved in: ../input/normalized-images/d249138214d3b8c5.jpg
# normalized image saved in: ../input/normalized-images/4ee1c2a240b0d025.jpg
# normalized image saved in: ../input/normalized-images/d3b6ad66087ec53e.jpg
# normalized image saved in: ../input/normalized-images/a539c03e2e8fb333.jpg
# normalized image saved in: ../input/normalized-images/3bdac4fced343058.jpg
# normalized image saved in: ../input/normalized-images/7a3cdd7f634347b2.jpg
# normalized image saved in: ../input/normalized-images/fe9f21b8bea1b0e9.jpg
# normalized image saved in: ../input/normalized-images/4462b17b9a586305.jpg
# normalized image saved in: ../input/normalized-images/b492d332c998992e.jpg
# normalized image saved in: ../input/normalized-images/4e9741ba48f00b20.jpg
# normalized image saved in: ../input/normalized-images/608a258f2d8c5f1d.jpg
# normalized image saved in: ../input/normalized-images/8a975d0f40e75d92.jpg
# normalized image saved in: ../input/normalized-images/029fa47531ed164f.jpg
# normalized image saved in: ../input/normalized-images/7fef89adc738c6c6.jpg
# normalized image saved in: ../input/normalized-images/2aafc87c3db2865f.jpg
# normalized image saved in: ../input/normalized-images/1c69057a966cdbb5.jpg
# normalized image saved in: ../input/normalized-images/12a1dc9f0e12ac81.jpg
# normalized image saved in: ../input/normalized-images/a3eeb8f0ffc16774.jpg
# normalized image saved in: ../input/normalized-images/df3d0d3c2587a2e5.jpg
# normalized image saved in: ../input/normalized-images/4286f5c7a7abc5ea.jpg
# normalized image saved in: ../input/normalized-images/45b47f9507207625.jpg
# normalized image saved in: ../input/normalized-images/13ab942ee91ca6e3.jpg
# normalized image saved in: ../input/normalized-images/af336b6894545a14.jpg
# normalized image saved in: ../input/normalized-images/144bed612777576f.jpg
# normalized image saved in: ../input/normalized-images/8f18de4e6003d20b.jpg
# normalized image saved in: ../input/normalized-images/7769014a974d8818.jpg
# normalized image saved in: ../input/normalized-images/d142f6f53cccce74.jpg
# normalized image saved in: ../input/normalized-images/bdca7869f5df73df.jpg
# normalized image saved in: ../input/normalized-images/ab6b9596b68c10a8.jpg
# normalized image saved in: ../input/normalized-images/4861fc624addf862.jpg
# normalized image saved in: ../input/normalized-images/2ce1776110ad9dd9.jpg
# normalized image saved in: ../input/normalized-images/c90f118b398643eb.jpg
# normalized image saved in: ../input/normalized-images/4005b3c46cfd2271.jpg
# normalized image saved in: ../input/normalized-images/817038b5e9e3708f.jpg
# normalized image saved in: ../input/normalized-images/ab4044d6ebec738b.jpg
# normalized image saved in: ../input/normalized-images/4d2dd6655c6a78a0.jpg
# normalized image saved in: ../input/normalized-images/ff77fc087ebd8c94.jpg
# normalized image saved in: ../input/normalized-images/b1284b0c580f1f0e.jpg
# normalized image saved in: ../input/normalized-images/efca6bc441fbe646.jpg
# normalized image saved in: ../input/normalized-images/bd8ff0136920dc63.jpg
# normalized image saved in: ../input/normalized-images/fdfa55f39f900720.jpg
# normalized image saved in: ../input/normalized-images/ace433804a240d68.jpg
# normalized image saved in: ../input/normalized-images/b95bf7e2ee4002e0.jpg
# normalized image saved in: ../input/normalized-images/817012f17ba20347.jpg
# normalized image saved in: ../input/normalized-images/2a66b8945e27af73.jpg
# normalized image saved in: ../input/normalized-images/d5ddaf1f620d05e7.jpg
# normalized image saved in: ../input/normalized-images/ffa4d8fb9f615e4a.jpg
# normalized image saved in: ../input/normalized-images/d73a3d43a0fd36a2.jpg
# normalized image saved in: ../input/normalized-images/154d8b9a4ea33057.jpg
# normalized image saved in: ../input/normalized-images/574331904d35c642.jpg
# normalized image saved in: ../input/normalized-images/d31993a27eb87b42.jpg
# normalized image saved in: ../input/normalized-images/7e9f119b71763495.jpg
# normalized image saved in: ../input/normalized-images/58f5f763e6ee6436.jpg
# normalized image saved in: ../input/normalized-images/0c7cc5085c993305.jpg
# normalized image saved in: ../input/normalized-images/4238151d336288a0.jpg
# normalized image saved in: ../input/normalized-images/3f428ab86d6eadd2.jpg
# normalized image saved in: ../input/normalized-images/5d643834e2785bf8.jpg
# normalized image saved in: ../input/normalized-images/f5766aae4ef18d3c.jpg
# normalized image saved in: ../input/normalized-images/a44a64f750bc9a86.jpg
# normalized image saved in: ../input/normalized-images/f9c19af18dab19c6.jpg
# normalized image saved in: ../input/normalized-images/5d466cc673ddb2f5.jpg
# normalized image saved in: ../input/normalized-images/d19ec5bb5ea0c70b.jpg
# normalized image saved in: ../input/normalized-images/27f5e1f236aed3f7.jpg
# normalized image saved in: ../input/normalized-images/ad87bca36f84d1b9.jpg
# normalized image saved in: ../input/normalized-images/6d4fd1401175f053.jpg
# normalized image saved in: ../input/normalized-images/feec8f4e9d9b2580.jpg
# normalized image saved in: ../input/normalized-images/df46b461dda81d98.jpg
# normalized image saved in: ../input/normalized-images/949ddf88fa6cf942.jpg
# normalized image saved in: ../input/normalized-images/b81640a03d08a591.jpg
# normalized image saved in: ../input/normalized-images/bfdfcdbba1852445.jpg
# normalized image saved in: ../input/normalized-images/b8958e31f66e1c46.jpg
# normalized image saved in: ../input/normalized-images/4e8c0670350159f1.jpg
# normalized image saved in: ../input/normalized-images/570e15f13081453b.jpg
# normalized image saved in: ../input/normalized-images/5d7a293014c97447.jpg
# normalized image saved in: ../input/normalized-images/d546341f3989e4af.jpg
# normalized image saved in: ../input/normalized-images/c642ca219c0da0fc.jpg
# normalized image saved in: ../input/normalized-images/015791cc5365f96c.jpg
# normalized image saved in: ../input/normalized-images/4b1fddcfbbd325ff.jpg
# normalized image saved in: ../input/normalized-images/1f85d65ca5616369.jpg
# normalized image saved in: ../input/normalized-images/c5917b8ce5bf1797.jpg
# normalized image saved in: ../input/normalized-images/10c45f54a467826d.jpg
# normalized image saved in: ../input/normalized-images/4efa79ff0b2be68e.jpg
# normalized image saved in: ../input/normalized-images/cf8425004fe9d28c.jpg
# normalized image saved in: ../input/normalized-images/85f5f173a2ffbf68.jpg
# normalized image saved in: ../input/normalized-images/6c48b9bccef71972.jpg
# normalized image saved in: ../input/normalized-images/f25244a134856a10.jpg
# normalized image saved in: ../input/normalized-images/acd5740fb4a56088.jpg
# normalized image saved in: ../input/normalized-images/9af21755494da0f4.jpg
# normalized image saved in: ../input/normalized-images/afe9e95f8988221c.jpg
# normalized image saved in: ../input/normalized-images/2e84ec6aa845c695.jpg
# normalized image saved in: ../input/normalized-images/07bc061f5252182c.jpg
# normalized image saved in: ../input/normalized-images/d05e5a0b5da51f25.jpg
# normalized image saved in: ../input/normalized-images/5c9989e5237b2917.jpg
# normalized image saved in: ../input/normalized-images/24fd45adc6a68b03.jpg
# normalized image saved in: ../input/normalized-images/28d2c81831c9602f.jpg
# normalized image saved in: ../input/normalized-images/ce38604ca0a226a7.jpg
# normalized image saved in: ../input/normalized-images/1aba544129aea768.jpg
# normalized image saved in: ../input/normalized-images/e630c40381ec049b.jpg
# normalized image saved in: ../input/normalized-images/c83a5e6dc6df4fc5.jpg
# normalized image saved in: ../input/normalized-images/68d088596e40cb98.jpg
# normalized image saved in: ../input/normalized-images/8d4fe4641881e11c.jpg
# normalized image saved in: ../input/normalized-images/a1b04aaab59898dd.jpg
# normalized image saved in: ../input/normalized-images/2ab3ae7ddd1c67c5.jpg
# normalized image saved in: ../input/normalized-images/6f4284df74245417.jpg
# normalized image saved in: ../input/normalized-images/4860c47380afb324.jpg
# normalized image saved in: ../input/normalized-images/cd7e4c413034c7dd.jpg
# ...
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/iostream.py", line 228, in _really_send
#     ctx.term()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "zmq/backend/cython/context.pyx", line 136, in zmq.backend.cython.context.Context.term
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc
#   File "<ipython-input-3-9ca2c854e3da>", line 5, in normalize_image
#     scaler = joblib.load(scaler_filename)
# KeyboardInterrupt
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/numpy_pickle.py", line 578, in load
#     obj = _unpickle(fobj, filename, mmap_mode)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/numpy_pickle.py", line 508, in _unpickle
#     obj = unpickler.load()
#   File "/usr/lib/python3.6/pickle.py", line 1050, in load
#     dispatch[key[0]](self)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/numpy_pickle.py", line 341, in load_build
#     self.stack.append(array_wrapper.read(self))
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/numpy_pickle.py", line 184, in read
#     array = self.read_array(unpickler)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/numpy_pickle.py", line 135, in read_array
#     read_size, "array data")
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/numpy_pickle_utils.py", line 638, in _read_bytes
#     r = fp.read(size - len(data))
# KeyboardInterrupt
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# normalized image saved in: ../input/normalized-images/80e1014a5a61c69c.jpg
# normalized image saved in: ../input/normalized-images/94b84af949d8f093.jpg
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# normalized image saved in: ../input/normalized-images/480aaa275157d9fa.jpg
# normalized image saved in: ../input/normalized-images/8c172774a35cf956.jpg
# normalized image saved in: ../input/normalized-images/5cabeebbc7d9deab.jpg
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# normalized image saved in: ../input/normalized-images/0cece118fd9e8cab.jpg
# normalized image saved in: ../input/normalized-images/c2a97faf1fd4720f.jpg
# normalized image saved in: ../input/normalized-images/ed43834395929bbf.jpg
# normalized image saved in: ../input/normalized-images/5e2efdc94ff2b9c2.jpg
# normalized image saved in: ../input/normalized-images/f9354302ec46dfa1.jpg
# normalized image saved in: ../input/normalized-images/e39a2b6670662209.jpg
# normalized image saved in: ../input/normalized-images/f59d5ccdfc0d5d50.jpg
# normalized image saved in: ../input/normalized-images/46334fc4f7cc88ff.jpg
# normalized image saved in: ../input/normalized-images/375a16d411319029.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3be04f160225> in <module>()
#       8 pool = Pool(processes=processes)  # Num of CPUs
#       9
# ---> 10 pool.map(normalize_image, dir_list, chunksize = 8)
#      11
#      12 pool.close()
#
# /usr/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
# normalized image saved in: ../input/normalized-images/727ed8eae11ac53a.jpg
# normalized image saved in: ../input/normalized-images/9f1b9178a14cf687.jpg
# normalized image saved in: ../input/normalized-images/a6262c121735d943.jpg
# normalized image saved in: ../input/normalized-images/c870784846aff3d3.jpg
# normalized image saved in: ../input/normalized-images/6ca5333f4481cd80.jpg
# normalized image saved in: ../input/normalized-images/9feef6f72dcf7d47.jpg
# normalized image saved in: ../input/normalized-images/a5b8eb56666a9384.jpg
# normalized image saved in: ../input/normalized-images/10fe38fd8754fd02.jpg
# normalized image saved in: ../input/normalized-images/9d07d202499f02db.jpg
# normalized image saved in: ../input/normalized-images/db2c136db71a33c2.jpg
# normalized image saved in: ../input/normalized-images/59c9e8b764a1054e.jpg
# normalized image saved in: ../input/normalized-images/9fe2eb45518eb8ad.jpg
# normalized image saved in: ../input/normalized-images/7f2591d6e43efb48.jpg
# normalized image saved in: ../input/normalized-images/a41337e6c14efe2e.jpg
# normalized image saved in: ../input/normalized-images/45833ba938575417.jpg
# normalized image saved in: ../input/normalized-images/c9e1cd0598d8deb6.jpg
# normalized image saved in: ../input/normalized-images/9dfc004e3a21bf63.jpg
# normalized image saved in: ../input/normalized-images/815cf06abb783342.jpg
# normalized image saved in: ../input/normalized-images/ef4589bba712d4fc.jpg
# normalized image saved in: ../input/normalized-images/9636a759aab99d45.jpg
# normalized image saved in: ../input/normalized-images/8675df06e2c96349.jpg
# normalized image saved in: ../input/normalized-images/d066ae42dbf6126e.jpg
# normalized image saved in: ../input/normalized-images/0f7f20f319b586fd.jpg
# normalized image saved in: ../input/normalized-images/cbea2b590335ab31.jpg
# normalized image saved in: ../input/normalized-images/d5b991ade93b8889.jpg
# normalized image saved in: ../input/normalized-images/dd0cd8cbc4fe41fd.jpg
# normalized image saved in: ../input/normalized-images/8b31b139f1cf1b5b.jpg
# normalized image saved in: ../input/normalized-images/e533150845db33ae.jpg
# normalized image saved in: ../input/normalized-images/0ae23d4868aa372e.jpg
# normalized image saved in: ../input/normalized-images/69039dedd20c1638.jpg
# normalized image saved in: ../input/normalized-images/7b9193b62b2b12f6.jpg
# normalized image saved in: ../input/normalized-images/1e316f11e3275cb4.jpg
# normalized image saved in: ../input/normalized-images/8612c0ff7f0035a8.jpg
# normalized image saved in: ../input/normalized-images/d1b6a088cb98df9d.jpg
# normalized image saved in: ../input/normalized-images/11ce4cfbfd4bd46a.jpg
# normalized image saved in: ../input/normalized-images/e8565219af739e6a.jpg
# normalized image saved in: ../input/normalized-images/49ecaa3151eea55a.jpg
# normalized image saved in: ../input/normalized-images/5ead075d439698e1.jpg
# normalized image saved in: ../input/normalized-images/69d927aff79d7e85.jpg
# normalized image saved in: ../input/normalized-images/bdb9c2961946b409.jpg
# normalized image saved in: ../input/normalized-images/759b10a22a1796bd.jpg
# normalized image saved in: ../input/normalized-images/9cc545d7e4754896.jpg
# normalized image saved in: ../input/normalized-images/4a28e82eea0944fe.jpg
# normalized image saved in: ../input/normalized-images/909fad76d25d48f2.jpg
# normalized image saved in: ../input/normalized-images/6fc940fe72aaea7d.jpg
# normalized image saved in: ../input/normalized-images/74fbd29f443cdec4.jpg
# normalized image saved in: ../input/normalized-images/9c578b8374ef5dab.jpg
# normalized image saved in: ../input/normalized-images/89a124584a74fe0d.jpg
# normalized image saved in: ../input/normalized-images/b6144c1b2f5aa55f.jpg
# normalized image saved in: ../input/normalized-images/fd69b02dedfeab8b.jpg
# normalized image saved in: ../input/normalized-images/eb499f324f69a97b.jpg
# normalized image saved in: ../input/normalized-images/59fe8d9d7fe9cf04.jpg
# normalized image saved in: ../input/normalized-images/68d143d7b674ad52.jpg
# normalized image saved in: ../input/normalized-images/069c971f9e8b09aa.jpg
# normalized image saved in: ../input/normalized-images/983f7fe4c58ee9f4.jpg
# normalized image saved in: ../input/normalized-images/80a4ef0213ea6d97.jpg
# normalized image saved in: ../input/normalized-images/c1d1d8fbfae50207.jpg
# normalized image saved in: ../input/normalized-images/8f6a94f32659b765.jpg
# normalized image saved in: ../input/normalized-images/d4aa3b6acf479a92.jpg
# normalized image saved in: ../input/normalized-images/33bbe4197f60cbc3.jpg
# normalized image saved in: ../input/normalized-images/9a279c885ad22229.jpg
# normalized image saved in: ../input/normalized-images/d1f23e840357c6a9.jpg
# normalized image saved in: ../input/normalized-images/48724a0a9310e46a.jpg
# normalized image saved in: ../input/normalized-images/2f2325777bdfdb7a.jpg
# normalized image saved in: ../input/normalized-images/bf79fa8b23a5c22d.jpg
# normalized image saved in: ../input/normalized-images/8aef2ce33b97c7e3.jpg
# normalized image saved in: ../input/normalized-images/86172f220dd06a65.jpg
# normalized image saved in: ../input/normalized-images/092262c1ee9bc53c.jpg
# normalized image saved in: ../input/normalized-images/083126250ae4b0c7.jpg
# normalized image saved in: ../input/normalized-images/bd8e270e4247c1f7.jpg
# normalized image saved in: ../input/normalized-images/7ddf70be2ba8b570.jpg
# normalized image saved in: ../input/normalized-images/f84237e9bd3ceaca.jpg
# normalized image saved in: ../input/normalized-images/1de7eb4f0e5690ae.jpg
# normalized image saved in: ../input/normalized-images/994870c0889a02e4.jpg
# normalized image saved in: ../input/normalized-images/d4c55e12f9736340.jpg
# normalized image saved in: ../input/normalized-images/05ae9f708d3fc38e.jpg
# normalized image saved in: ../input/normalized-images/7897960f77a17a9f.jpg
# normalized image saved in: ../input/normalized-images/1b7348ba50300ae2.jpg
# normalized image saved in: ../input/normalized-images/bcf2c9f93b175bae.jpg
# normalized image saved in: ../input/normalized-images/77c9ed6f88e72eb8.jpg
# normalized image saved in: ../input/normalized-images/7d2c462481a0cf91.jpg
# normalized image saved in: ../input/normalized-images/6b2f8cacf4151335.jpg
# normalized image saved in: ../input/normalized-images/d1aa3957a00acc94.jpg
# normalized image saved in: ../input/normalized-images/3f4a46bb17b3fea5.jpg
# normalized image saved in: ../input/normalized-images/95566f914c0e3ad8.jpg
# normalized image saved in: ../input/normalized-images/d067d539dfe595ba.jpg
# normalized image saved in: ../input/normalized-images/c1c29744dc2b40de.jpg
# normalized image saved in: ../input/normalized-images/5b6c149769bc153b.jpg
# normalized image saved in: ../input/normalized-images/61fe151060efe7c9.jpg
# normalized image saved in: ../input/normalized-images/88b2e1e89dbf06dd.jpg
# normalized image saved in: ../input/normalized-images/9121a268ea6a874b.jpg
# normalized image saved in: ../input/normalized-images/684a28e97d7a92d4.jpg
# normalized image saved in: ../input/normalized-images/dbbde69740647a5d.jpg
# normalized image saved in: ../input/normalized-images/f33844a791cd4d3c.jpg
# normalized image saved in: ../input/normalized-images/4c3b4835e84f4f5e.jpg
# normalized image saved in: ../input/normalized-images/a9d448d64d94236c.jpg
# normalized image saved in: ../input/normalized-images/bca50acc6e9f5a23.jpg
# normalized image saved in: ../input/normalized-images/beb0defbf9b9e768.jpg
# normalized image saved in: ../input/normalized-images/655942c0d7b4e11a.jpg
# normalized image saved in: ../input/normalized-images/623ea79974b6651f.jpg
# normalized image saved in: ../input/normalized-images/3f709fddddc4fd3d.jpg
# normalized image saved in: ../input/normalized-images/dcc02d781aa26be8.jpg
# normalized image saved in: ../input/normalized-images/8951a932e348197e.jpg
# normalized image saved in: ../input/normalized-images/8c95f5bb6e90f53d.jpg
# normalized image saved in: ../input/normalized-images/db58b08c8bd880a7.jpg
# normalized image saved in: ../input/normalized-images/fd2c115cdea992a4.jpg
# normalized image saved in: ../input/normalized-images/a938e93cfdb525b4.jpg
# normalized image saved in: ../input/normalized-images/c1512e3302c22738.jpg
# normalized image saved in: ../input/normalized-images/742091d64d5b1791.jpg
# normalized image saved in: ../input/normalized-images/2b332ff021df49e6.jpg
# normalized image saved in: ../input/normalized-images/f22aaa0d3399ed97.jpg
# normalized image saved in: ../input/normalized-images/5bfed9ce1e9cf0bd.jpg
# normalized image saved in: ../input/normalized-images/72d5f34fa499de75.jpg
# normalized image saved in: ../input/normalized-images/6a001bf12e68511c.jpg
# normalized image saved in: ../input/normalized-images/302945c41fb7e501.jpg
# normalized image saved in: ../input/normalized-images/9f7844793f56ca44.jpg
# normalized image saved in: ../input/normalized-images/114936fb488fdbda.jpg
# normalized image saved in: ../input/normalized-images/fab5bf6366c9c2d4.jpg
# normalized image saved in: ../input/normalized-images/e1762c81ca036734.jpg
# normalized image saved in: ../input/normalized-images/0a0bda72541927c1.jpg
# normalized image saved in: ../input/normalized-images/c54e13aedc26e836.jpg
# normalized image saved in: ../input/normalized-images/714e560189c2d9a3.jpg
# normalized image saved in: ../input/normalized-images/88e1c1b811ad8b7b.jpg
# normalized image saved in: ../input/normalized-images/305681cf3e8ee202.jpg
# normalized image saved in: ../input/normalized-images/8abe467a0e85bedb.jpg
# normalized image saved in: ../input/normalized-images/4708cbe9015db9da.jpg
# normalized image saved in: ../input/normalized-images/cee6dd974667b70a.jpg
# normalized image saved in: ../input/normalized-images/b22cf348491aeaa7.jpg
# normalized image saved in: ../input/normalized-images/a35f5dd7358bb757.jpg
# normalized image saved in: ../input/normalized-images/80f69aa639ae3f67.jpg
# normalized image saved in: ../input/normalized-images/b99415eb39174bb2.jpg
# normalized image saved in: ../input/normalized-images/bd2ca716f7aca599.jpg
# normalized image saved in: ../input/normalized-images/a4f61a306c9dc93c.jpg
# normalized image saved in: ../input/normalized-images/579e4113df81773c.jpg
# normalized image saved in: ../input/normalized-images/73f228ad22762546.jpg
# normalized image saved in: ../input/normalized-images/b137986fae2819b9.jpg
# normalized image saved in: ../input/normalized-images/5583d9697432d9ce.jpg
# normalized image saved in: ../input/normalized-images/1f25b04883996637.jpg
# normalized image saved in: ../input/normalized-images/650850f0345aab4e.jpg
# normalized image saved in: ../input/normalized-images/bdd9b84f4168936a.jpg
# normalized image saved in: ../input/normalized-images/a65029fbe95a47f7.jpg
# normalized image saved in: ../input/normalized-images/cfb602a7b5813b87.jpg
# normalized image saved in: ../input/normalized-images/e38ea87887dac0f0.jpg
